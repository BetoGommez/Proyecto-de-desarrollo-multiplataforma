# %% [markdown]
# # SQL

# %%
import pandas as pd
import sqlite3

# %%
data_folder_in = "datos/{}"
data_folder_out = "datos/escritura/{}"

database = 'chinook.db'

# %%
cnx = sqlite3.connect(data_folder_in.format(database))

# %%
df = pd.read_sql_query("SELECT * FROM playlists", cnx)
df
# Out:
#     PlaylistId                        Name
# 0            1                       music
# 1            2                      movies
# 2            3                    tv shows
# 3            4                  audiobooks
# 4            5                  90’s music
# 5            6                  audiobooks
# 6            7                      movies
# 7            8                       music
# 8            9                music videos
# 9           10                    tv shows
# 10          11             brazilian music
# 11          12                   classical
# 12          13   classical 101 - deep cuts
# 13          14  classical 101 - next steps
# 14          15  classical 101 - the basics
# 15          16                      grunge
# 16          17         heavy metal classic
# 17          18                 on-the-go 1
# 18          81                       music
# 19          82                      movies
# 20          83                    tv shows
# 21          84                  audiobooks
# 22          85                  90’s music
# 23          86                  audiobooks
# 24          87                      movies
# 25          88                       music
# 26          89                music videos
# 27          90                    tv shows
# 28          91             brazilian music
# 29          92                   classical
# 30          93   classical 101 - deep cuts
# 31          94  classical 101 - next steps
# 32          95  classical 101 - the basics
# 33          96                      grunge
# 34          97         heavy metal classic
# 35          98                 on-the-go 1

# %%
df['Name'] = df['Name'].str.lower()

# %%
df
# Out:
#     PlaylistId                        Name
# 0            1                       music
# 1            2                      movies
# 2            3                    tv shows
# 3            4                  audiobooks
# 4            5                  90’s music
# 5            6                  audiobooks
# 6            7                      movies
# 7            8                       music
# 8            9                music videos
# 9           10                    tv shows
# 10          11             brazilian music
# 11          12                   classical
# 12          13   classical 101 - deep cuts
# 13          14  classical 101 - next steps
# 14          15  classical 101 - the basics
# 15          16                      grunge
# 16          17         heavy metal classic
# 17          18                 on-the-go 1
# 18          81                       music
# 19          82                      movies
# 20          83                    tv shows
# 21          84                  audiobooks
# 22          85                  90’s music
# 23          86                  audiobooks
# 24          87                      movies
# 25          88                       music
# 26          89                music videos
# 27          90                    tv shows
# 28          91             brazilian music
# 29          92                   classical
# 30          93   classical 101 - deep cuts
# 31          94  classical 101 - next steps
# 32          95  classical 101 - the basics
# 33          96                      grunge
# 34          97         heavy metal classic
# 35          98                 on-the-go 1

# %%
df.to_sql('playlists', con=cnx, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.to_sql('playlists', con=cnx, if_exists='append')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:2188, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    2178 table = SQLiteTable(
#    2179     name,
#    2180     self,
#    (...)
#    2185     dtype=dtype,
#    2186 )
#    2187 table.create()
# -> 2188 return table.insert(chunksize, method)
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:946, in SQLTable.insert(self, chunksize, method)
#     943     break
#     945 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 946 num_inserted = exec_insert(conn, keys, chunk_iter)
#     947 # GH 46891
#     948 if is_integer(num_inserted):
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:1894, in SQLiteTable._execute_insert(self, conn, keys, data_iter)
#    1892 def _execute_insert(self, conn, keys, data_iter) -> int:
#    1893     data_list = list(data_iter)
# -> 1894     conn.executemany(self.insert_statement(num_rows=1), data_list)
#    1895     return conn.rowcount
#
# OperationalError: table playlists has no column named index

# %%
df.to_sql('playlists', con=cnx, if_exists='append', index=False)
# Out:
# 36

# %%
df['PlaylistId'] = df['PlaylistId'] + 20
df
# Out:
#     PlaylistId                        Name
# 0           21                       music
# 1           22                      movies
# 2           23                    tv shows
# 3           24                  audiobooks
# 4           25                  90’s music
# 5           26                  audiobooks
# 6           27                      movies
# 7           28                       music
# 8           29                music videos
# 9           30                    tv shows
# 10          31             brazilian music
# 11          32                   classical
# 12          33   classical 101 - deep cuts
# 13          34  classical 101 - next steps
# 14          35  classical 101 - the basics
# 15          36                      grunge
# 16          37         heavy metal classic
# 17          38                 on-the-go 1
# 18         101                       music
# 19         102                      movies
# 20         103                    tv shows
# 21         104                  audiobooks
# 22         105                  90’s music
# 23         106                  audiobooks
# 24         107                      movies
# 25         108                       music
# 26         109                music videos
# 27         110                    tv shows
# 28         111             brazilian music
# 29         112                   classical
# 30         113   classical 101 - deep cuts
# 31         114  classical 101 - next steps
# 32         115  classical 101 - the basics
# 33         116                      grunge
# 34         117         heavy metal classic
# 35         118                 on-the-go 1

# %%
df.to_sql('playlists', con=cnx, if_exists='append', index=False, index_label='PlaylistId')
# Out:
# 36

# %%
df = pd.read_sql_query("SELECT * FROM playlists", cnx)
df
# Out:
#      PlaylistId                        Name
# 0             1                       music
# 1             2                      movies
# 2             3                    tv shows
# 3             4                  audiobooks
# 4             5                  90’s music
# ..          ...                         ...
# 103         114  classical 101 - next steps
# 104         115  classical 101 - the basics
# 105         116                      grunge
# 106         117         heavy metal classic
# 107         118                 on-the-go 1
#
# [108 rows x 2 columns]

# %%
df['Name'] = df['Name'].str.lower()
df
# Out:
#      PlaylistId                        Name
# 0             1                       music
# 1             2                      movies
# 2             3                    tv shows
# 3             4                  audiobooks
# 4             5                  90’s music
# ..          ...                         ...
# 103         114  classical 101 - next steps
# 104         115  classical 101 - the basics
# 105         116                      grunge
# 106         117         heavy metal classic
# 107         118                 on-the-go 1
#
# [108 rows x 2 columns]

# %%
df.to_sql('playlists', con=cnx, if_exists='replace', index=False, index_label='PlaylistId')
# Out:
# 108

# %%
df = pd.read_sql_query("SELECT * FROM playlists", cnx)
df
# Out:
#      PlaylistId                        Name
# 0             1                       music
# 1             2                      movies
# 2             3                    tv shows
# 3             4                  audiobooks
# 4             5                  90’s music
# ..          ...                         ...
# 103         114  classical 101 - next steps
# 104         115  classical 101 - the basics
# 105         116                      grunge
# 106         117         heavy metal classic
# 107         118                 on-the-go 1
#
# [108 rows x 2 columns]

# %%
df = pd.read_sql_query("""
    SELECT * FROM playlists p, playlist_track pt
    WHERE p.PlaylistId = pt.PlaylistId
""", cnx)
df
# Out:
#        PlaylistId                 Name  PlaylistId  TrackId
# 0               1                music           1     3402
# 1               1                music           1     3402
# 2               1                music           1     3389
# 3               1                music           1     3389
# 4               1                music           1     3390
# ...           ...                  ...         ...      ...
# 17425          17  heavy metal classic          17     2096
# 17426          17  heavy metal classic          17     3290
# 17427          17  heavy metal classic          17     3290
# 17428          18          on-the-go 1          18      597
# 17429          18          on-the-go 1          18      597
#
# [17430 rows x 4 columns]

# %%
df.to_csv(data_folder_out.format('chinook.csv'), index=False, sep=";", decimal=",")
