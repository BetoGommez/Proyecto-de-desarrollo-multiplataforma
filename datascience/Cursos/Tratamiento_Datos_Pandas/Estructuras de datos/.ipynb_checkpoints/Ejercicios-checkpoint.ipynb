# %% [markdown]
# # Ejercicios

# %%
import pandas as pd
import numpy as np
from pathlib import Path


data_path = Path('./data')

data = pd.read_csv(data_path / 'house.csv', sep=',' )

data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
data.query('bedrooms == 8')
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 1500  2014-05-28 00:00:00  1970000.0       8.0       3.50         4440
# 3911  2014-07-03 00:00:00   340000.0       8.0       2.75         2790
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 1500      6480     2.0           0     3          5        3140
# 3911      6695     1.0           0     0          3        1470
#
#       sqft_basement  yr_built  yr_renovated               street       city  \
# 1500           1300      1959             0      1210 22nd Ave E    Seattle
# 3911           1320      1977          2004  17512 Corliss Ave N  Shoreline
#
#       statezip country
# 1500  WA 98112     USA
# 3911  WA 98133     USA

# %%
data['bedrooms'].min()
# Out:
# 0.0

# %%
data['bedrooms'].max()
# Out:
# 9.0

# %%
data['precio_planta'] = data['price']/data['floors']
data['precio_planta']
# Out:
# 0       2.086667e+05
# 1       1.192000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    2.671667e+05
# 4597    2.084521e+05
# 4598    2.034000e+05
# 4599    1.103000e+05
# Name: precio_planta, Length: 4600, dtype: float64

# %%
data['price']
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country  \
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA
#
#    precio_planta
# 0   2.086667e+05
# 1   1.192000e+06
# 2   3.420000e+05
# 3   4.200000e+05
# 4   5.500000e+05

# %% [markdown]
# ### Ejercicio 2

# %%
data.loc[216]['price']
# Out:
# 485000.0

# %%
data['price'][216]
# Out:
# 485000.0

# %%
data['bedrooms'][215:223]
# Out:
# 215    3.0
# 216    3.0
# 217    5.0
# 218    3.0
# 219    2.0
# 220    3.0
# 221    3.0
# 222    3.0
# Name: bedrooms, dtype: float64

# %%
aleatorio = data.sample(frac=0.15)

# %%
aleatorio.query('bedrooms==3 or bedrooms==4 and price<300000')
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 1687  2014-06-02 00:00:00  1000000.0       3.0       2.50         2730
# 2907  2014-06-19 00:00:00   232603.0       3.0       1.75         1750
# 1766  2014-06-03 00:00:00   713250.0       3.0       2.00         2050
# 3527  2014-06-27 00:00:00   672500.0       3.0       2.25         2400
# 1839  2014-06-04 00:00:00   270000.0       3.0       2.25         2080
# ...                   ...        ...       ...        ...          ...
# 4026  2014-07-07 00:00:00   229500.0       3.0       1.00         1230
# 2757  2014-06-18 00:00:00   325000.0       3.0       2.75         2200
# 2391  2014-06-12 00:00:00   299995.0       3.0       2.50         1970
# 840   2014-05-16 00:00:00   377500.0       3.0       2.25         1410
# 748   2014-05-15 00:00:00   695000.0       3.0       2.50         4560
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 1687      5832     2.0           0     0          3        2730
# 2907     11461     2.0           0     0          4        1750
# 1766      9000     1.0           0     0          4        2050
# 3527      5300     1.5           0     0          4        1250
# 1839      4252     1.5           0     0          3        1550
# ...        ...     ...         ...   ...        ...         ...
# 4026      6000     1.0           0     0          4        1230
# 2757      7000     1.0           0     0          4        1280
# 2391      7500     2.0           0     0          3        1970
# 840       1377     2.0           0     0          3        1290
# 748      17622     2.0           0     0          4        3800
#
#       sqft_basement  yr_built  yr_renovated                  street  \
# 1687              0      1998          2006        13428 NE 12th Pl
# 2907              0      1976          1992         1002 Pike St NE
# 1766              0      1951          1999        2416 70th Ave SE
# 3527           1150      1939          1989        8022 22nd Ave NW
# 1839            530      2003             0      20442 137th Ave SE
# ...             ...       ...           ...                     ...
# 4026              0      1967             0         1605 21st St NE
# 2757            920      1977             0       16304 128th Pl SE
# 2391              0      1988          2000     4809 Mill Pond Loop
# 840             120      2005             0  2012 NW Boulder Way Dr
# 748             760      1986             0        1315 232nd Pl NE
#
#                city  statezip country  precio_planta
# 1687       Bellevue  WA 98005     USA  500000.000000
# 2907         Auburn  WA 98002     USA  116301.500000
# 1766  Mercer Island  WA 98040     USA  713250.000000
# 3527        Seattle  WA 98117     USA  448333.333333
# 1839           Kent  WA 98042     USA  180000.000000
# ...             ...       ...     ...            ...
# 4026         Auburn  WA 98002     USA  229500.000000
# 2757         Renton  WA 98058     USA  325000.000000
# 2391         Auburn  WA 98092     USA  149997.500000
# 840        Issaquah  WA 98027     USA  188750.000000
# 748       Sammamish  WA 98074     USA  347500.000000
#
# [333 rows x 19 columns]

# %%
#
data.index.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 2
#       1 #localizacion_array = {"localizacion": "street","city","statezip","country"}
# ----> 2 data.index[2].name
#
# AttributeError: 'int' object has no attribute 'name'

# %%
data.loc["street":"city"]
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated, street, city, statezip, country, precio_planta]
# Index: []

# %%
data.columns.loc["street"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 data.columns.loc["street"]
#
# AttributeError: 'Index' object has no attribute 'loc'

# %%
# Out:
# Index(['street', 'city', 'statezip', 'country'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4600, step=1)

# %%
localizacion_array = {"localizacion": data.columns[14:18],"características": data.columns[0:14]+data.columns[18:]}

# %%
multindex = {};
for i in localizacion_array:
    for j in i:
      
        multindex.append({i,j})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 5
#       2 for i in localizacion_array:
#       3     for j in i:
# ----> 5         multindex.append({i,j})
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
mulx
# Out:
# MultiIndex([('l', 'o', 'c', 'a', 'l', 'i', 'z', 'a', 'c', 'i', 'o', 'n'),
#             ('c', 'a', 'r', 'a', 'c', 't', 'e', 'r', 'í', 's', 't', 'i')],
#            )

# %%
data.columns = mulx
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 data.columns = mulx
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:823, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     822     labels = ensure_index(labels)
# --> 823     self._mgr.set_axis(axis, labels)
#     824     self._clear_item_cache()
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:230, in BaseBlockManager.set_axis(self, axis, new_labels)
#     228 def set_axis(self, axis: int, new_labels: Index) -> None:
#     229     # Caller is responsible for ensuring we have an Index object.
# --> 230     self._validate_set_axis(axis, new_labels)
#     231     self.axes[axis] = new_labels
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 19 elements, new values have 2 elements
