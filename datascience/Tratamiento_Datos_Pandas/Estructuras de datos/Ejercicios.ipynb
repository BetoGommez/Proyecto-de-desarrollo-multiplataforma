# %% [markdown]
# # Ejercicios

# %%
import pandas as pd
import numpy as np
from pathlib import Path


data_path = Path('./data')

data = pd.read_csv(data_path / 'house.csv', sep=',' )

data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
data.query('bedrooms == 8')
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 1500  2014-05-28 00:00:00  1970000.0       8.0       3.50         4440
# 3911  2014-07-03 00:00:00   340000.0       8.0       2.75         2790
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 1500      6480     2.0           0     3          5        3140
# 3911      6695     1.0           0     0          3        1470
#
#       sqft_basement  yr_built  yr_renovated               street       city  \
# 1500           1300      1959             0      1210 22nd Ave E    Seattle
# 3911           1320      1977          2004  17512 Corliss Ave N  Shoreline
#
#       statezip country
# 1500  WA 98112     USA
# 3911  WA 98133     USA

# %%
data['bedrooms'].min()
# Out:
# 0.0

# %%
data['bedrooms'].max()
# Out:
# 9.0

# %%
data['precio_planta'] = data['price']/data['floors']
data['precio_planta']
# Out:
# 0       2.086667e+05
# 1       1.192000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    2.671667e+05
# 4597    2.084521e+05
# 4598    2.034000e+05
# 4599    1.103000e+05
# Name: precio_planta, Length: 4600, dtype: float64

# %%
data['price']
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %% [markdown]
# ### Ejercicio 2

# %%
data.loc[216]['price']
# Out:
# 485000.0

# %%
data['price'][216]
# Out:
# 485000.0

# %%
data['bedrooms'][215:223]
# Out:
# 215    3.0
# 216    3.0
# 217    5.0
# 218    3.0
# 219    2.0
# 220    3.0
# 221    3.0
# 222    3.0
# Name: bedrooms, dtype: float64

# %%
aleatorio = data.sample(frac=0.15)

# %%
aleatorio.query('bedrooms==3 or bedrooms==4 and price<300000')
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 2715  2014-06-17 00:00:00  430000.0       3.0       1.00          980
# 554   2014-05-13 00:00:00  289000.0       3.0       1.00         1090
# 347   2014-05-08 00:00:00  385000.0       3.0       1.75         1890
# 1274  2014-05-23 00:00:00  464600.0       3.0       1.75         1120
# 479   2014-05-12 00:00:00  560000.0       3.0       2.00         2560
# ...                   ...       ...       ...        ...          ...
# 3713  2014-07-01 00:00:00  219950.0       3.0       1.50         1620
# 1404  2014-05-27 00:00:00  480000.0       3.0       1.00         1150
# 4106  2014-07-08 00:00:00  148226.0       3.0       1.00         1400
# 3492  2014-06-26 00:00:00  219500.0       3.0       1.00         1090
# 1701  2014-06-02 00:00:00  316000.0       3.0       2.25         2130
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
data.loc["street":"city"]
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated, street, city, statezip, country, precio_planta]
# Index: []

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4600, step=1)

# %%
localizacion_array = {"localizacion": data.columns[14:18],"características": data.columns[0:14]+data.columns[18:]}
localizacion_array
# Out:
# {'localizacion': Index(['street', 'city', 'statezip', 'country'], dtype='object'),
#  'características': Index(['dateprecio_planta', 'priceprecio_planta', 'bedroomsprecio_planta',
#         'bathroomsprecio_planta', 'sqft_livingprecio_planta',
#         'sqft_lotprecio_planta', 'floorsprecio_planta',
#         'waterfrontprecio_planta', 'viewprecio_planta',
#         'conditionprecio_planta', 'sqft_aboveprecio_planta',
#         'sqft_basementprecio_planta', 'yr_builtprecio_planta',
#         'yr_renovatedprecio_planta'],
#        dtype='object')}

# %%
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...
