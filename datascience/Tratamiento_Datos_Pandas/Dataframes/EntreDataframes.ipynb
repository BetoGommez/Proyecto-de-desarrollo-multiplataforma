# %%
import pandas as pd
import numpy as np

from pathlib import Path

data_path= Path("./data")

# %%
df = pd.read_csv(data_path / 'pivot_data.csv')
df.head()
# Out:
#          date variable     value  variable2
# 0  2000-01-03        A -0.272917          1
# 1  2000-01-04        A  0.098333          2
# 2  2000-01-05        A  0.273676          3
# 3  2000-01-03        B -0.585902          1
# 4  2000-01-04        B  0.959133          2

# %%
df[df['variable']=="A"]
# Out:
#          date variable     value  variable2
# 0  2000-01-03        A -0.272917          1
# 1  2000-01-04        A  0.098333          2
# 2  2000-01-05        A  0.273676          3

# %%
_ = df.pivot(index='date',columns='variable', values='value')

# %%
_
# Out:
# variable           A         B         C         D
# date
# 2000-01-03 -0.272917 -0.585902 -0.164357 -1.242624
# 2000-01-04  0.098333  0.959133 -1.049870 -0.532904
# 2000-01-05  0.273676  1.447109 -0.097525  0.348482

# %%
_ = df.pivot(index='variable',columns='date', values='value')
_
# Out:
# date      2000-01-03  2000-01-04  2000-01-05
# variable
# A          -0.272917    0.098333    0.273676
# B          -0.585902    0.959133    1.447109
# C          -0.164357   -1.049870   -0.097525
# D          -1.242624   -0.532904    0.348482

# %%
_ = df.pivot(index=['date','variable'], columns='variable2', values='value')
_
# Out:
# variable2                   1         2         3
# date       variable
# 2000-01-03 A        -0.272917       NaN       NaN
#            B        -0.585902       NaN       NaN
#            C        -0.164357       NaN       NaN
#            D        -1.242624       NaN       NaN
# 2000-01-04 A              NaN  0.098333       NaN
#            B              NaN  0.959133       NaN
#            C              NaN -1.049870       NaN
#            D              NaN -0.532904       NaN
# 2000-01-05 A              NaN       NaN  0.273676
#            B              NaN       NaN  1.447109
#            C              NaN       NaN -0.097525
#            D              NaN       NaN  0.348482

# %%
_.index
# Out:
# MultiIndex([('2000-01-03', 'A'),
#             ('2000-01-03', 'B'),
#             ('2000-01-03', 'C'),
#             ('2000-01-03', 'D'),
#             ('2000-01-04', 'A'),
#             ('2000-01-04', 'B'),
#             ('2000-01-04', 'C'),
#             ('2000-01-04', 'D'),
#             ('2000-01-05', 'A'),
#             ('2000-01-05', 'B'),
#             ('2000-01-05', 'C'),
#             ('2000-01-05', 'D')],
#            names=['date', 'variable'])

# %% [markdown]
# ### stack y unstack

# %%
stack = _.stack().to_frame()
stack
# Out:
#                                       0
# date       variable variable2
# 2000-01-03 A        1         -0.272917
#            B        1         -0.585902
#            C        1         -0.164357
#            D        1         -1.242624
# 2000-01-04 A        2          0.098333
#            B        2          0.959133
#            C        2         -1.049870
#            D        2         -0.532904
# 2000-01-05 A        3          0.273676
#            B        3          1.447109
#            C        3         -0.097525
#            D        3          0.348482

# %%
stack = stack.stack()
stack
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 stack = stack.stack()
#       2 stack
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'stack'

# %% [markdown]
# ### pivot table

# %%
pd.pivot_table(data = df, index='date',columns='variable',values='value')
# Out:
# variable           A         B         C         D
# date
# 2000-01-03 -0.272917 -0.585902 -0.164357 -1.242624
# 2000-01-04  0.098333  0.959133 -1.049870 -0.532904
# 2000-01-05  0.273676  1.447109 -0.097525  0.348482

# %%
pd.pivot_table(data = df, index='date',columns='variable2',values='value',aggfunc='max')
# Out:
# variable2         1         2         3
# date
# 2000-01-03 -0.56645       NaN       NaN
# 2000-01-04      NaN -0.131327       NaN
# 2000-01-05      NaN       NaN  0.492936
